# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
path='/content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5'
print(os.listdir(path))
# Out:
# ['vehicle detection.ipynb', 'trafic_data', 'yolov5']

# %%
os.chdir('/content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5')

# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 67.4.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 KB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !ls
# Out:
# benchmarks.py	 detect.py   __pycache__       segment	       val.py
# CITATION.cff	 export.py   README.md	       setup.cfg       yolov5
# classify	 hubconf.py  README.zh-CN.md   train.py        yolov5s.pt
# CONTRIBUTING.md  LICENSE     requirements.txt  tutorial.ipynb
# data		 models      runs	       utils

# %%
os.chdir('/content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/yolov5')

# %%
# !ls
# Out:
# benchmarks.py	 detect.py   __pycache__       segment	       val.py
# CITATION.cff	 export.py   README.md	       setup.cfg       yolov5
# classify	 hubconf.py  README.zh-CN.md   train.py        yolov5s.pt
# CONTRIBUTING.md  LICENSE     requirements.txt  tutorial.ipynb
# data		 models      runs	       utils

# %%
# !python train.py --img 416 --batch 16 --epochs 5 --data data/car.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/car.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-107-g7a972e8 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 30 --data data/car.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/car.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-107-g7a972e8 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
os.chdir('/content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/yolov5')

# %%
import torch
model = torch.hub.load('ultralytics/yolov5', 'custom', path='runs/train/exp5/weights/best.pt')  # local model
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-2-23 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# [Errno 2] No such file or directory: '/usr/local/lib/python3.8/dist-packages/pyparsing-3.0.9.dist-info/METADATA'
# Model summary: 157 layers, 7066762 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
# !python detect.py
# Out:
# detect: weights=yolov5s.pt, source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-107-g7a972e8 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 19.7ms
# image 2/2 /content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 13.5ms
# Speed: 0.5ms pre-process, 16.6ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
 # !python detect.py --weights runs/train/exp7/weights/best.pt --img 416 --source /content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/trafic_data/valid/images
# Out:
# detect: weights=['runs/train/exp7/weights/best.pt'], source=/content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/trafic_data/valid/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-107-g7a972e8 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7066762 parameters, 0 gradients, 15.9 GFLOPs
# image 1/300 /content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/trafic_data/valid/images/Pias--139-_jpg.rf.3480cbf4cd5e0ba990e49896b2a3d9aa.jpg: 256x416 2 cars, 15.6ms
# ...

# %%
os.chdir('/content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/trafic_data/valid/images')

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/yolov5/runs/detect/exp4/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
os.chdir('/content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5')

# %%
output = !python yolov5/detect.py --source /content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/trafic_data/valid/images/1.jpg --weights '/content/drive/My Drive/Colab_Notebooks/car_prediction_using_yolov5/yolov5/runs/train/exp5/weights/best.pt'
print(output)
# Out:
# ["\x1b\x1bdetect: \x1bweights=['/content/drive/My Drive/Colab_Notebooks/car_prediction_using_yolov5/yolov5/runs/train/exp5/weights/best.pt'], source=/content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/trafic_data/valid/images/1.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1", 'YOLOv5 🚀 v7.0-107-g7a972e8 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)', '', 'Fusing layers... ', 'Model summary: 157 layers, 7066762 parameters, 0 gradients, 15.9 GFLOPs', 'image 1/1 /content/drive/MyDrive/Colab_Notebooks/car_prediction_using_yolov5/trafic_data/valid/images/1.jpg: 384x640 4 cars, 18.8ms', 'Speed: 0.4ms
# ...
